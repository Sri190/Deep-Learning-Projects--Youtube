# %%
#Import All The Libraries
import pandas as pd
import numpy as np
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Import the Dataset
df_1=pd.read_csv("data.csv")

#Data Cleaning
df=df_1.drop("Unnamed: 32",axis=1)
df['diagnosis']=df['diagnosis'].map({'M':0,'B':1})

#Data Preprocessing
scalar=StandardScaler()
X=df.drop("diagnosis",axis=1)
y=df["diagnosis"]
x=pd.DataFrame(scalar.fit_transform(X),columns=X.columns)

#Train-Test Split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

#Model Training
input_dim = x_train.shape[1]  
model = keras.Sequential([
    keras.layers.Input(shape=(input_dim,)),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(32,activation='relu'),
    keras.layers.Dense(16,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
es=EarlyStopping(patience=20,restore_best_weights=True)
history=model.fit(x_train,y_train,validation_split=0.1,epochs=20,batch_size=32,callbacks=es)

#Model Testing and accuracy
loss,Accuracy=model.evaluate(x_test,y_test)
print(f"Test Loss :{loss:.4f}")
print(f"Test Accuracy :{Accuracy:.4f}")
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.6900 - loss: 0.6113 - val_accuracy: 0.9565 - val_loss: 0.3961
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9618 - loss: 0.3521 - val_accuracy: 0.9348 - val_loss: 0.2356
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9723 - loss: 0.1956 - val_accuracy: 0.9565 - val_loss: 0.1621
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9814 - loss: 0.1151 - val_accuracy: 0.9565 - val_loss: 0.1220
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9880 - loss: 0.0768 - val_accuracy: 0.9565 - val_loss: 0.0991
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9892 - loss: 0.0579 - val_accuracy: 0.9783 - val_loss: 0.0831
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9914 - loss: 0.0472 - val_accuracy: 0.9783 - val_loss: 0.0732
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9932 - loss: 0.0404 - val_accuracy: 0.9783 - val_loss: 0.0661
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9932 - loss: 0.0354 - val_accuracy: 0.9783 - val_loss: 0.0605
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9971 - loss: 0.0315 - val_accuracy: 0.9783 - val_loss: 0.0545
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9971 - loss: 0.0285 - val_accuracy: 0.9783 - val_loss: 0.0487
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9971 - loss: 0.0260 - val_accuracy: 0.9783 - val_loss: 0.0435
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9971 - loss: 0.0239 - val_accuracy: 0.9783 - val_loss: 0.0379
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9971 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0326
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9971 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0295
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9971 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0256
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9971 - loss: 0.0181 - val_accuracy: 1.0000 - val_loss: 0.0223
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9971 - loss: 0.0167 - val_accuracy: 1.0000 - val_loss: 0.0195
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9971 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9971 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0151
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9620 - loss: 0.1134
# Test Loss :0.1038
# Test Accuracy :0.9649
