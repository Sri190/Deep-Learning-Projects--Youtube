# %%
#Import All Libraries
import pandas as pd
import numpy as np
import tensorflow as tf
tf.random.set_seed(3)
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from sklearn.model_selection import train_test_split


#Import the Dataset
df=pd.read_csv("creditcard.csv")

#Data in Underfitted. So,Change its shape
legit=df[df.Class==0]
fraud=df[df.Class==1]
legit_sample=legit.sample(n=492)
new_df=pd.concat([legit_sample,fraud],axis=0)

#Data-Preprocessing
scalar=StandardScaler()
X=new_df.drop('Class',axis=1)
y=new_df['Class']
x=pd.DataFrame(scalar.fit_transform(X),columns=X.columns)

#Train-Test Split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=42)

#Model Training.
model = keras.Sequential([
    keras.layers.Input(shape=(30,)),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(32,activation='relu'),
    keras.layers.Dense(16,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(x_train,y_train,validation_split=0.1,epochs=20,batch_size=32)

#Model Accuracy
loss,Accuracy=model.evaluate(x_test,y_test)
print(f"Test Loss :{loss:.4f}")
print(f"Test Accuracy :{Accuracy:.4f}")
# Out:
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5257 - loss: 0.7146 - val_accuracy: 0.8608 - val_loss: 0.5312
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8907 - loss: 0.4753 - val_accuracy: 0.8734 - val_loss: 0.3809
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9076 - loss: 0.3289 - val_accuracy: 0.8987 - val_loss: 0.2686
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9264 - loss: 0.2467 - val_accuracy: 0.9494 - val_loss: 0.1981
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9279 - loss: 0.2009 - val_accuracy: 0.9620 - val_loss: 0.1566
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9469 - loss: 0.1708 - val_accuracy: 0.9747 - val_loss: 0.1343
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9511 - loss: 0.1514 - val_accuracy: 0.9747 - val_loss: 0.1213
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9547 - loss: 0.1385 - val_accuracy: 0.9747 - val_loss: 0.1130
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9542 - loss: 0.1287 - val_accuracy: 0.9747 - val_loss: 0.1079
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9569 - loss: 0.1209 - val_accuracy: 0.9747 - val_loss: 0.1046
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9666 - loss: 0.1144 - val_accuracy: 0.9747 - val_loss: 0.1024
# Epoch 12/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9681 - loss: 0.1089 - val_accuracy: 0.9620 - val_loss: 0.1001
# Epoch 13/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9681 - loss: 0.1039 - val_accuracy: 0.9620 - val_loss: 0.0983
# Epoch 14/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9671 - loss: 0.0992 - val_accuracy: 0.9620 - val_loss: 0.0969
# Epoch 15/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9691 - loss: 0.0945 - val_accuracy: 0.9620 - val_loss: 0.0954
# Epoch 16/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9721 - loss: 0.0900 - val_accuracy: 0.9620 - val_loss: 0.0952
# Epoch 17/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9725 - loss: 0.0861 - val_accuracy: 0.9620 - val_loss: 0.0950
# Epoch 18/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9725 - loss: 0.0818 - val_accuracy: 0.9620 - val_loss: 0.0948
# Epoch 19/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9728 - loss: 0.0776 - val_accuracy: 0.9620 - val_loss: 0.0950
# Epoch 20/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9728 - loss: 0.0736 - val_accuracy: 0.9620 - val_loss: 0.0956
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9460 - loss: 0.1226
# Test Loss :0.1007
# Test Accuracy :0.9594
